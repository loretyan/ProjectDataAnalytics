# %% [markdown]
# # Geographical persentation of the stadiums

# %%
# %pip install folium

import pandas as pd
import numpy as np
import folium
# Out:
# Requirement already satisfied: folium in /home/codespace/.python/current/lib/python3.12/site-packages (0.19.4)
# Requirement already satisfied: branca>=0.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /home/codespace/.local/lib/python3.12/site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.12/site-packages (from folium) (2.2.0)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/codespace/.python/current/lib/python3.12/site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->folium) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->folium) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
# CSV-Datei mit den Stadiondaten laden
csv_file_path = "stadien_map.csv"
stadion_data = pd.read_csv(csv_file_path)

# Zentrum der Karte auf Deutschland setzen
m = folium.Map(location=[51.1657, 10.4515], zoom_start=6)

# Marker für jedes Stadion hinzufügen
for index, row in stadion_data.iterrows():
    if not pd.isna(row["x-Koordinaten"]) and not pd.isna(row["y-Koordinaten"]):
        folium.Marker(
            location=[row["x-Koordinaten"], row["y-Koordinaten"]],
            popup=f'{row["Verein"]} - {row["Stadionname"]}',
            tooltip=row["Verein"]
        ).add_to(m)

# Layer control
folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e3eab04e55244c21e8d5e616ae4b509 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e3eab04e55244c21e8d5e616ae4b509&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e3eab04e55244c21e8d5e616ae4b509 = L.map(
#                 &quot;map_9e3eab04e55244c21e8d5e616ae4b509&quot;,
#                 {
#                     center: [51.1657, 10.4515],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7330fcf470773ff4ceebe868f2231bc2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7330fcf470773ff4ceebe868f2231bc2.addTo(map_9e3eab04e55244c21e8d5e616ae4b509);
#
#
#             var marker_ce5b97851b3340cf8534600fdd5808dd = L.marker(
#                 [48.2188, 11.6247],
#                 {
# }
#             ).addTo(map_9e3eab04e55244c21e8d5e616ae4b509);
#
#
#         var popup_b94997384e78329c00dc30c864c3e5e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb825a4e96bcffa91ae614c7debf4232 = $(`&lt;div id=&quot;html_eb825a4e96bcffa91ae614c7debf4232&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bayern München - Allianz Arena&lt;/div&gt;`)[0];
#                 popup_b94997384e78329c00dc30c864c3e5e9.setContent(html_eb825a4e96bcffa91ae614c7debf4232);
#
#
#
#         marker_ce5b97851b3340cf8534600fdd5808dd.bindPopup(popup_b94997384e78329c00dc30c864c3e5e9)
#         ;
#
#
#
#
#             marker_ce5b97851b3340cf8534600fdd5808dd.bindTooltip(
#                 `&lt;div&gt;
#                      Bayern München
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c5e679ec8c880b4bec1962e0832322a8 = L.marker(
#                 [51.038, 6.9852],
#                 {
# }
#             ).addTo(map_9e3eab04e55244c21e8d5e616ae4b509);
#
#
#         var popup_b6549c3ca6dc0ef6236200af688f1c32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15b60553fe959c371e5ff56f18c54247 = $(`&lt;div id=&quot;html_15b60553fe959c371e5ff56f18c54247&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bayer Leverkusen - BayArena&lt;/div&gt;`)[0];
#                 popup_b6549c3ca6dc0ef6236200af688f1c32.setContent(html_15b60553fe959c371e5ff56f18c54247);
#
#
#
#         marker_c5e679ec8c880b4bec1962e0832322a8.bindPopup(popup_b6549c3ca6dc0ef6236200af688f1c32)
#         ;
#
#
#
#
#             marker_c5e679ec8c880b4bec1962e0832322a8.bindTooltip(
#                 `&lt;div&gt;
#                      Bayer Leverkusen
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6f3b1e5d7718ebe98ed31c1d95891284 = L.marker(
#                 [51.345, 12.348],
#                 {
# }
#             ).addTo(map_9e3eab04e55244c21e8d5e616ae4b509);
#
#
#         var popup_ed2ebe74b0cc584dc0607cd616c8918a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8b503b72d94bfdeaccd4b3d05d8480f = $(`&lt;div id=&quot;html_f8b503b72d94bfdeaccd4b3d05d8480f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;RB Leipzig - Red Bull Arena&lt;/div&gt;`)[0];
#                 popup_ed2ebe74b0cc584dc0607cd616c8918a.setContent(html_f8b503b72d94bfdeaccd4b3d05d8480f);
#
#
#
#         marker_6f3b1e5d7718ebe98ed31c1d95891284.bindPopup(popup_ed2ebe74b0cc584dc0607cd616c8918a)
#         ;
#
#
#
#
#             marker_6f3b1e5d7718ebe98ed31c1d95891284.bindTooltip(
#                 `&lt;div&gt;
#                      RB Leipzig
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6abf8fba8053da65cd6b4dcfafe0000e = L.marker(
#                 [51.4926, 7.4519],
#                 {
# }
#             ).addTo(map_9e3eab04e55244c21e8d5e616ae4b509);
#
#
#         var popup_1b9ded073ee994baf1a20b247a3dccb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bec6e32e6d3717a0cc63693d5b62814 = $(`&lt;div id=&quot;html_1bec6e32e6d3717a0cc63693d5b62814&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Borussia Dortmund - Signal Iduna Park&lt;/div&gt;`)[0];
#                 popup_1b9ded073ee994baf1a20b247a3dccb5.setContent(html_1bec6e32e6d3717a0cc63693d5b62814);
#
#
#
#         marker_6abf8fba8053da65cd6b4dcfafe0000e.bindPopup(popup_1b9ded073ee994baf1a20b247a3dccb5)
#         ;
#
#
#
#
#             marker_6abf8fba8053da65cd6b4dcfafe0000e.bindTooltip(
#                 `&lt;div&gt;
#                      Borussia Dortmund
#                  &lt;/div&gt;`
